# %%
# === 1. IMPORTS ===
import os
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as transforms

# === 2. CONFIGURATION ===
DATASET_DIR = "./cartoonset10k/"   # à adapter selon ta structure
IMG_SIZE = 64                      # cible 64x64
BATCH_SIZE = 32

# %%
# Transforms appliqués aux images
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),  # reshape 64x64
    transforms.ToTensor(),
])
